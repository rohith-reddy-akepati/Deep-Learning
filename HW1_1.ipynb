# %%
import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import TensorDataset, DataLoader
import torch.utils.data as Data
from torch.autograd import Variable

from sklearn.model_selection import train_test_split

import numpy as np
import math

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # HW1 : 1.1 Simulate a Function

# %%
def SinFunc(x_input):
    y = (np.sin(5*math.pi*x_input))/(5*math.pi*x_input) 
    return y

def SignFunc(x_input):
    y = np.sign(np.sin(5*math.pi*x_input))
    return y

X = np.linspace(1e-6, 1, 60000)
# y =  SignFunc(X)
y =  SinFunc(X)

X = X.reshape(-1,1)
y = y.reshape(-1,1)

fig, ax = plt.subplots(1,2,figsize=(20,4))
ax[0].plot(X, SinFunc(X))
ax[0].set_title('Sin(5*pi*x)/(5*pi*x) plot')
ax[1].plot(X, SignFunc(X))
ax[1].set_title('Sgn(Sin(5*pi*x)) plot')
plt.show()

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42,test_size=0.2)
# print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

model0 = torch.nn.Sequential(
            nn.Linear(1, 5),
            nn.ReLU(),
            nn.Linear(5, 10),
            nn.ReLU(),
            nn.Linear(10, 10),
            nn.ReLU(),
            nn.Linear(10, 10),
            nn.ReLU(),
            nn.Linear(10, 10),
            nn.ReLU(),
            nn.Linear(10, 10),
            nn.ReLU(),
            nn.Linear(10, 5),
            nn.ReLU(),
            nn.Linear(5, 1),
        )

model1 = torch.nn.Sequential(
            nn.Linear(1, 10),
            nn.ReLU(),
            nn.Linear(10, 18),
            nn.ReLU(),
            nn.Linear(18, 15),
            nn.ReLU(),
            nn.Linear(15, 4),
            nn.ReLU(),
            nn.Linear(4,1)
        )

model2 = torch.nn.Sequential(
            nn.Linear(1, 190),
            nn.ReLU(),
            nn.Linear(190,1)
        )

models = [model0, model1, model2]

BATCH_SIZE=32
LEARNING_RATE = 1e-2
MAX_EPOCHS = 100

optimizers = []
criterions = []

for model in models:
    model.train()
    criterions.append(nn.MSELoss())
    optimizers.append(optim.SGD(model.parameters(), lr=LEARNING_RATE))
    

training_samples = Data.TensorDataset(torch.from_numpy(X_train), torch.from_numpy(y_train))
train_data_loader = Data.DataLoader(training_samples, batch_size=BATCH_SIZE, shuffle=True)

test_samples = Data.TensorDataset(torch.from_numpy(X_test), torch.from_numpy(y_test))
test_data_loader = Data.DataLoader(test_samples, batch_size=BATCH_SIZE, shuffle=True)

model_loss = []

for model,optimizer,criterion in zip(models,optimizers,criterions):
    print(model)
    pytorch_total_params = sum(p.numel() for p in model.parameters())
    print("Parameters: ",pytorch_total_params)
    
    train_loss = []
    
    for epoch in range(MAX_EPOCHS):
        avg_loss=[]
        correct = 0
        for batch_idx, (data, target) in enumerate(train_data_loader):
            data, target = Variable(data), Variable(target)
            
            optimizer.zero_grad()
            output = model(data.float())
            loss = criterion(output, target.float())
            
            #print(batch_idx, loss.data[0])
            loss.backward()
            
            optimizer.step()
            
            avg_loss.append(loss.item())
            #correct += (output == target.float()).sum()
                
            #if(epoch+1)%200==0 and batch_idx%100==0:
            if (epoch+1)%100==0 and batch_idx%500==0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(epoch+1, batch_idx * len(data), len(train_data_loader.dataset),100. * batch_idx / len(train_data_loader), np.average(avg_loss)))

        train_loss.append(np.average(avg_loss))
        
    model_loss.append(train_loss)
    print("Training Done!!!\n","*"*100)
# Out:
# Sequential(
#   (0): Linear(in_features=1, out_features=5, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=5, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=10, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=10, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=10, out_features=10, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=10, out_features=10, bias=True)
#   (11): ReLU()
#   (12): Linear(in_features=10, out_features=5, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=5, out_features=1, bias=True)
# )
# Parameters:  571
# Train Epoch: 100 [0/48000 (0%)]	Loss: 0.107698
# Train Epoch: 100 [16000/48000 (33%)]	Loss: 0.087702
# Train Epoch: 100 [32000/48000 (67%)]	Loss: 0.087702
# Training Done!!!
#  ****************************************************************************************************
# Sequential(
#   (0): Linear(in_features=1, out_features=10, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=10, out_features=18, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=18, out_features=15, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=15, out_features=4, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=4, out_features=1, bias=True)
# )
# Parameters:  572
# Train Epoch: 100 [0/48000 (0%)]	Loss: 0.000046
# Train Epoch: 100 [16000/48000 (33%)]	Loss: 0.000071
# Train Epoch: 100 [32000/48000 (67%)]	Loss: 0.000072
# Training Done!!!
#  ****************************************************************************************************
# Sequential(
#   (0): Linear(in_features=1, out_features=190, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=190, out_features=1, bias=True)
# )
# Parameters:  571
# Train Epoch: 100 [0/48000 (0%)]	Loss: 0.001093
# Train Epoch: 100 [16000/48000 (33%)]	Loss: 0.000496
# Train Epoch: 100 [32000/48000 (67%)]	Loss: 0.000489
# Training Done!!!
#  ****************************************************************************************************

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))

Labels = ['Model0','Model1','Model2']
Colors = ['c', 'm', 'y']

ax[0].plot(np.linspace(1e-6, 1, 2000), SinFunc(np.linspace(1e-6, 1, 2000)), c='c', label='Original data')
ax[0].set_title("Actuals vs Predictions")

ax[1].set_title('Loss')
ax[1].set_yscale('log') 
for idx, model in enumerate(models):
    
    # plot  the predictions and the difference
    model.eval()

    prediction = model(Variable(torch.Tensor(np.linspace(1e-6, 1, 2000).reshape(-1,1))))
    prediction = prediction.data.numpy()

    ax[0].plot(np.linspace(1e-6, 1, 2000), prediction, c= Colors[idx], label=Labels[idx])

    ax[1].plot(model_loss[idx], c= Colors[idx], label=Labels[idx])

ax[0].legend()   
ax[1].legend()
plt.show()

# %%
train_loss
# Out:
# [0.044793723824744426,
#  0.022346474201108017,
#  0.013437378118125102,
#  0.009529950780483583,
#  0.007682177634133647,
#  0.006665954317587117,
#  0.006037048877682537,
#  0.0055403092716199654,
#  0.005116708502949526,
#  0.004724340759295349,
#  0.004382405896205455,
#  0.00407823978868934,
#  0.0038218709482656173,
#  0.0036034116401181867,
#  0.003390439681553592,
#  0.003215252151945606,
#  0.0030471252367521326,
#  0.002886476132009799,
#  0.002742007586872205,
#  0.002604213691704596,
#  0.0024725086537655443,
#  0.0023566739081870764,
#  0.0022421761236619204,
#  0.0021442678071713697,
#  0.002042180312409376,
#  0.001956519169732928,
#  0.0018654002822780361,
#  0.0017841939096494266,
#  0.0017118649349237482,
#  0.0016438701829950635,
#  0.001584084162216944,
#  0.0015191138793791954,
#  0.0014655016253624733,
#  0.0014124926743097604,
#  0.0013678532821359112,
#  0.0013221376148673395,
#  0.0012774605799932032,
#  0.001237944341536301,
#  0.001203995556066123,
#  0.001168696913906994,
#  0.0011373372236266732,
#  0.0011034300760754073,
#  0.0010739302860262494,
#  0.0010466337428273011,
#  0.0010273620672135925,
#  0.0010024117523959528,
#  0.0009760465945388812,
#  0.0009558428803575225,
#  0.0009367169015652811,
#  0.0009171356344789577,
#  0.0008984184385432551,
#  0.0008816159349905017,
#  0.0008634734486113303,
#  0.0008487732750169623,
#  0.0008323367094077791,
#  0.0008187973734457046,
#  0.0008046704650429698,
#  0.000791398145937516,
#  0.0007764279674350595,
#  0.0007655133515169533,
#  0.000753689741618776,
#  0.0007394446930848063,
#  0.000730299223777062,
#  0.0007180511672825863,
#  0.0007092884190496989,
#  0.000700552289102537,
#  0.0006909357157031384,
#  0.0006806143612484447,
#  0.0006717889898379023,
#  0.0006622171821266724,
#  0.0006557334757720431,
#  0.0006481981993711088,
#  0.0006407436381365793,
#  0.000633614091212318,
#  0.0006262782107611807,
#  0.0006192781246597103,
#  0.0006123497226411321,
#  0.0006055174614593852,
#  0.0006007309865478116,
#  0.0005930928354306767,
#  0.0005862148755404632,
#  0.0005787302878452465,
#  0.0005738640495110304,
#  0.0005673351734294556,
#  0.0005604104940624287,
#  0.0005539796011677633,
#  0.0005489882403053344,
#  0.000541367901295113,
#  0.0005384471419092733,
#  0.0005347620541094027,
#  0.0005278369439668798,
#  0.0005222472036160373,
#  0.0005174902878643479,
#  0.0005122828067202742,
#  0.0005075280585345657,
#  0.0005044217104344474,
#  0.0004975159619837844,
#  0.000492931116517866,
#  0.0004888382640104586,
#  0.0004842927976472614]

# %% [markdown]
# # HW1 : 1.1 Train on Actual Tasks - MNIST

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
train_data = datasets.MNIST(
    root='data',
    train=True,
    transform=ToTensor(),
    download = True,
)

test_data = datasets.MNIST(
    root='data',
    train=False,
    transform=ToTensor(),
    download = False,
)

# %%
print(train_data)
print(train_data.data.size())
print(train_data.targets.size())
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()
# torch.Size([60000, 28, 28])
# torch.Size([60000])

# %%
figure = plt.figure(figsize=(10,8))
cols, rows = 5,5
for i in range(1, cols*rows+1):
    sample_idx = torch.randint(len(train_data), size=(1,)).item()
    img, label = train_data[sample_idx]
    figure.add_subplot(rows,cols,i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap='gray')
plt.show()

# %%
loaders = {'train': Data.DataLoader(train_data,
                                               batch_size=100,
                                               shuffle=True,
                                               num_workers=1),
          'test': Data.DataLoader(test_data,
                                             batch_size=100,
                                             shuffle=True,
                                             num_workers=1)
          }

loaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x7f1e0a56f450>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x7f1e0a5116d0>}

# %%
class CNN2(nn.Module):
    def __init__(self):
        super(CNN2, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        )
        # fully connected layer, output 10 classes
        self.out = nn.Linear(16 * 14 * 14, 10)
    def forward(self, x):
        x = self.conv1(x)
        # flatten the output of conv2 to (batch_size, 16 * 7 * 7)
        x = x.view(x.size(0), -1)       
        output = self.out(x)
        return output, x    # return x for visualization

class CNN1(nn.Module):
    def __init__(self):
        super(CNN1, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        )
        self.conv2 = nn.Sequential(         
            nn.Conv2d(16, 32, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        # fully connected layer, output 10 classes
        self.out = nn.Linear(32 * 7 * 7, 10)
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        # flatten the output of conv2 to (batch_size, 32 * 7 * 7)
        x = x.view(x.size(0), -1)       
        output = self.out(x)
        return output, x    # return x for visualization

class CNN0(nn.Module):
    def __init__(self):
        super(CNN0, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        )
        self.conv2 = nn.Sequential(         
            nn.Conv2d(16, 32, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        self.conv3 = nn.Sequential(         
            nn.Conv2d(32, 64, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        self.conv4 = nn.Sequential(         
            nn.Conv2d(64, 128, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        # fully connected layer, output 10 classes
        self.out = nn.Linear(128, 10)
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        # flatten the output of conv2 to (batch_size, 128 * 1 * 1)
        x = x.view(-1, 128)  
        output = self.out(x)
        return output, x    # return x for visualization

class CNN3(nn.Module):
    def __init__(self):
        super(CNN3, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=5)
        self.conv3 = nn.Conv2d(32,64, kernel_size=5)
        self.fc1 = nn.Linear(3*3*64, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        #x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(F.max_pool2d(self.conv3(x),2))
        x = F.dropout(x, p=0.5, training=self.training)
        x = x.view(-1,3*3*64 )
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1), x
    
class DNN1(nn.Module):
    def __init__(self):
        super(DNN1, self).__init__()
        self.linear1 = nn.Linear(784,250)
        self.linear2 = nn.Linear(250,100)
        self.linear3 = nn.Linear(100,10)
    
    def forward(self,X):
        X = X.view(-1,784)
        X = F.relu(self.linear1(X))
        X = F.relu(self.linear2(X))
        X = self.linear3(X)
        return F.log_softmax(X, dim=1), X
    
class DNN0(nn.Module):
    def __init__(self):
        super(DNN0, self).__init__()
        self.linear1 = nn.Linear(784,100)
        self.linear2 = nn.Linear(100,100)
        self.linear3 = nn.Linear(100,10)       
    
    def forward(self,X):
        X = X.view(-1,784)
        X = F.relu(self.linear1(X))
        for i in range(15):
            X = F.relu(self.linear2(X))
        X = self.linear3(X)
        return F.log_softmax(X, dim=1), X
    
class DNN2(nn.Module):
    def __init__(self):
        super(DNN2, self).__init__()
        self.linear1 = nn.Linear(784,280)
        self.linear2 = nn.Linear(280,10)
    
    def forward(self,X):
        X = X.view(-1,784)
        X = F.relu(self.linear1(X))
        X = self.linear2(X)
        return F.log_softmax(X, dim=1), X
    
cnn_models = [CNN0(), CNN1(), CNN2(), CNN3()]
dnn_models = [DNN0(), DNN1(), DNN2()]

# %%
loss_functions = []
optimizers = []
num_epochs = 30

for model in cnn_models:
    model.train()
    optimizers.append(optim.Adam(model.parameters(), lr = 0.01))
    loss_functions.append(nn.CrossEntropyLoss())

model_loss=[]
model_accuracy=[]
    
for model, optimizer, loss_func in zip(cnn_models,optimizers,loss_functions):
    print(model)
    # Train the model
    total_step = len(loaders['train'])
    
    train_loss =[]
    train_acc = []
    for epoch in range(num_epochs):
        correct=0
        b_loss=[]
        b_acc=[]
        for i, (images, labels) in enumerate(loaders['train']):
            
            # gives batch data, normalize x when iterate train_loader
            b_x = Variable(images) # batch x
            b_y = Variable(labels)   # batch y
            output = model(b_x)[0]               
            loss = loss_func(output, b_y)
            
            # clear gradients for this training step   
            optimizer.zero_grad()           
            
            # backpropagation, compute gradients 
            loss.backward()    
            # apply gradients             
            optimizer.step() 
            
            predicted = torch.max(output.data, 1)[1]
            correct += (predicted==b_y).sum()
            
            b_loss.append(loss.item())
            b_acc.append(float(correct)*100/float(100*(i+1)))
            
            if (i+1)%200==0 and epoch%2==0:
                print ('Epoch done[{}/{}], Step [{}/{}], Loss: {:.4f}, and Accuracy: {:.3f}%'.format(epoch + 1, num_epochs, i + 1, total_step, b_loss[-1],b_acc[-1]))
        train_loss.append(np.average(b_loss))
        train_acc.append(np.average(b_acc))
     
    model_loss.append(train_loss)
    model_accuracy.append(train_acc)
    print("Training completed!!!\n","*"*100)
# Out:
# CNN0(
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=128, out_features=10, bias=True)
# )
# Epoch done[1/30], Step [200/600], Loss: 2.2983, and Accuracy: 10.870%
# Epoch done[1/30], Step [400/600], Loss: 2.2928, and Accuracy: 10.932%
# Epoch done[1/30], Step [600/600], Loss: 2.3023, and Accuracy: 11.102%
# Epoch done[3/30], Step [200/600], Loss: 2.2988, and Accuracy: 11.195%
# Epoch done[3/30], Step [400/600], Loss: 2.3056, and Accuracy: 11.277%
# Epoch done[3/30], Step [600/600], Loss: 2.2902, and Accuracy: 11.210%
# Epoch done[5/30], Step [200/600], Loss: 2.3115, and Accuracy: 10.900%
# Epoch done[5/30], Step [400/600], Loss: 2.3009, and Accuracy: 10.970%
# Epoch done[5/30], Step [600/600], Loss: 2.2940, and Accuracy: 11.087%
# Epoch done[7/30], Step [200/600], Loss: 2.2935, and Accuracy: 11.390%
# Epoch done[7/30], Step [400/600], Loss: 2.2978, and Accuracy: 11.290%
# Epoch done[7/30], Step [600/600], Loss: 2.3087, and Accuracy: 11.107%
# Epoch done[9/30], Step [200/600], Loss: 2.2979, and Accuracy: 11.110%
# Epoch done[9/30], Step [400/600], Loss: 2.3002, and Accuracy: 11.135%
# Epoch done[9/30], Step [600/600], Loss: 2.3072, and Accuracy: 10.983%
# Epoch done[11/30], Step [200/600], Loss: 2.2989, and Accuracy: 10.765%
# Epoch done[11/30], Step [400/600], Loss: 2.2986, and Accuracy: 11.150%
# Epoch done[11/30], Step [600/600], Loss: 2.3070, and Accuracy: 11.173%
# Epoch done[13/30], Step [200/600], Loss: 2.3087, and Accuracy: 10.865%
# Epoch done[13/30], Step [400/600], Loss: 2.3041, and Accuracy: 10.925%
# Epoch done[13/30], Step [600/600], Loss: 2.3004, and Accuracy: 11.078%
# Epoch done[15/30], Step [200/600], Loss: 2.2994, and Accuracy: 10.750%
# Epoch done[15/30], Step [400/600], Loss: 2.3024, and Accuracy: 10.805%
# Epoch done[15/30], Step [600/600], Loss: 2.2996, and Accuracy: 10.992%
# Epoch done[17/30], Step [200/600], Loss: 2.3029, and Accuracy: 11.085%
# Epoch done[17/30], Step [400/600], Loss: 2.3096, and Accuracy: 11.210%
# Epoch done[17/30], Step [600/600], Loss: 2.2840, and Accuracy: 11.145%
# Epoch done[19/30], Step [200/600], Loss: 2.2926, and Accuracy: 11.110%
# Epoch done[19/30], Step [400/600], Loss: 2.3022, and Accuracy: 11.175%
# Epoch done[19/30], Step [600/600], Loss: 2.2988, and Accuracy: 11.038%
# Epoch done[21/30], Step [200/600], Loss: 2.3028, and Accuracy: 11.190%
# Epoch done[21/30], Step [400/600], Loss: 2.2981, and Accuracy: 11.258%
# Epoch done[21/30], Step [600/600], Loss: 2.3087, and Accuracy: 11.118%
# Epoch done[23/30], Step [200/600], Loss: 2.2913, and Accuracy: 11.380%
# Epoch done[23/30], Step [400/600], Loss: 2.3135, and Accuracy: 10.990%
# Epoch done[23/30], Step [600/600], Loss: 2.2998, and Accuracy: 11.075%
# Epoch done[25/30], Step [200/600], Loss: 2.3006, and Accuracy: 10.495%
# Epoch done[25/30], Step [400/600], Loss: 2.2950, and Accuracy: 10.985%
# Epoch done[25/30], Step [600/600], Loss: 2.2921, and Accuracy: 11.135%
# Epoch done[27/30], Step [200/600], Loss: 2.3032, and Accuracy: 11.035%
# Epoch done[27/30], Step [400/600], Loss: 2.3159, and Accuracy: 11.050%
# Epoch done[27/30], Step [600/600], Loss: 2.3026, and Accuracy: 11.115%
# Epoch done[29/30], Step [200/600], Loss: 2.3110, and Accuracy: 10.955%
# Epoch done[29/30], Step [400/600], Loss: 2.3149, and Accuracy: 11.210%
# Epoch done[29/30], Step [600/600], Loss: 2.3015, and Accuracy: 11.095%
# Training completed!!!
#  ****************************************************************************************************
# CNN1(
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=1568, out_features=10, bias=True)
# )
# Epoch done[1/30], Step [200/600], Loss: 0.0762, and Accuracy: 91.770%
# Epoch done[1/30], Step [400/600], Loss: 0.0444, and Accuracy: 94.630%
# Epoch done[1/30], Step [600/600], Loss: 0.0510, and Accuracy: 95.642%
# Epoch done[3/30], Step [200/600], Loss: 0.0131, and Accuracy: 98.600%
# Epoch done[3/30], Step [400/600], Loss: 0.0164, and Accuracy: 98.560%
# Epoch done[3/30], Step [600/600], Loss: 0.0121, and Accuracy: 98.482%
# Epoch done[5/30], Step [200/600], Loss: 0.0811, and Accuracy: 98.895%
# Epoch done[5/30], Step [400/600], Loss: 0.0052, and Accuracy: 98.823%
# Epoch done[5/30], Step [600/600], Loss: 0.0524, and Accuracy: 98.718%
# Epoch done[7/30], Step [200/600], Loss: 0.0079, and Accuracy: 99.035%
# Epoch done[7/30], Step [400/600], Loss: 0.0290, and Accuracy: 98.927%
# Epoch done[7/30], Step [600/600], Loss: 0.0125, and Accuracy: 98.897%
# Epoch done[9/30], Step [200/600], Loss: 0.0022, and Accuracy: 99.060%
# Epoch done[9/30], Step [400/600], Loss: 0.0787, and Accuracy: 98.922%
# Epoch done[9/30], Step [600/600], Loss: 0.0687, and Accuracy: 98.888%
# Epoch done[11/30], Step [200/600], Loss: 0.0249, and Accuracy: 99.310%
# Epoch done[11/30], Step [400/600], Loss: 0.0529, and Accuracy: 99.047%
# Epoch done[11/30], Step [600/600], Loss: 0.0785, and Accuracy: 99.057%
# Epoch done[13/30], Step [200/600], Loss: 0.0206, and Accuracy: 99.390%
# Epoch done[13/30], Step [400/600], Loss: 0.0009, and Accuracy: 99.325%
# Epoch done[13/30], Step [600/600], Loss: 0.0458, and Accuracy: 99.178%
# Epoch done[15/30], Step [200/600], Loss: 0.0010, and Accuracy: 99.235%
# Epoch done[15/30], Step [400/600], Loss: 0.0216, and Accuracy: 99.263%
# Epoch done[15/30], Step [600/600], Loss: 0.1122, and Accuracy: 99.203%
# Epoch done[17/30], Step [200/600], Loss: 0.0146, and Accuracy: 99.150%
# Epoch done[17/30], Step [400/600], Loss: 0.0100, and Accuracy: 99.160%
# Epoch done[17/30], Step [600/600], Loss: 0.0013, and Accuracy: 99.140%
# Epoch done[19/30], Step [200/600], Loss: 0.0001, and Accuracy: 99.435%
# Epoch done[19/30], Step [400/600], Loss: 0.0060, and Accuracy: 99.375%
# Epoch done[19/30], Step [600/600], Loss: 0.0000, and Accuracy: 99.352%
# Epoch done[21/30], Step [200/600], Loss: 0.0227, and Accuracy: 99.395%
# Epoch done[21/30], Step [400/600], Loss: 0.1314, and Accuracy: 99.418%
# Epoch done[21/30], Step [600/600], Loss: 0.0000, and Accuracy: 99.318%
# Epoch done[23/30], Step [200/600], Loss: 0.0000, and Accuracy: 99.505%
# Epoch done[23/30], Step [400/600], Loss: 0.0713, and Accuracy: 99.418%
# Epoch done[23/30], Step [600/600], Loss: 0.0189, and Accuracy: 99.387%
# Epoch done[25/30], Step [200/600], Loss: 0.0059, and Accuracy: 99.400%
# Epoch done[25/30], Step [400/600], Loss: 0.1863, and Accuracy: 99.415%
# Epoch done[25/30], Step [600/600], Loss: 0.0088, and Accuracy: 99.375%
# Epoch done[27/30], Step [200/600], Loss: 0.0011, and Accuracy: 99.420%
# Epoch done[27/30], Step [400/600], Loss: 0.4822, and Accuracy: 99.483%
# Epoch done[27/30], Step [600/600], Loss: 0.1830, and Accuracy: 99.422%
# Epoch done[29/30], Step [200/600], Loss: 0.0000, and Accuracy: 99.525%
# Epoch done[29/30], Step [400/600], Loss: 0.0048, and Accuracy: 99.528%
# Epoch done[29/30], Step [600/600], Loss: 0.0127, and Accuracy: 99.517%
# Training completed!!!
#  ****************************************************************************************************
# CNN2(
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=3136, out_features=10, bias=True)
# )
# Epoch done[1/30], Step [200/600], Loss: 0.0651, and Accuracy: 91.245%
# Epoch done[1/30], Step [400/600], Loss: 0.1169, and Accuracy: 94.118%
# Epoch done[1/30], Step [600/600], Loss: 0.0673, and Accuracy: 95.328%
# Epoch done[3/30], Step [200/600], Loss: 0.0441, and Accuracy: 98.815%
# Epoch done[3/30], Step [400/600], Loss: 0.0043, and Accuracy: 98.745%
# Epoch done[3/30], Step [600/600], Loss: 0.0447, and Accuracy: 98.658%
# Epoch done[5/30], Step [200/600], Loss: 0.0126, and Accuracy: 99.160%
# Epoch done[5/30], Step [400/600], Loss: 0.0174, and Accuracy: 99.120%
# Epoch done[5/30], Step [600/600], Loss: 0.1385, and Accuracy: 99.038%
# Epoch done[7/30], Step [200/600], Loss: 0.0109, and Accuracy: 99.380%
# Epoch done[7/30], Step [400/600], Loss: 0.0020, and Accuracy: 99.323%
# Epoch done[7/30], Step [600/600], Loss: 0.0071, and Accuracy: 99.218%
# Epoch done[9/30], Step [200/600], Loss: 0.0399, and Accuracy: 99.505%
# Epoch done[9/30], Step [400/600], Loss: 0.0035, and Accuracy: 99.353%
# Epoch done[9/30], Step [600/600], Loss: 0.0003, and Accuracy: 99.342%
# Epoch done[11/30], Step [200/600], Loss: 0.0991, and Accuracy: 99.335%
# Epoch done[11/30], Step [400/600], Loss: 0.0044, and Accuracy: 99.330%
# Epoch done[11/30], Step [600/600], Loss: 0.0262, and Accuracy: 99.312%
# Epoch done[13/30], Step [200/600], Loss: 0.0000, and Accuracy: 99.535%
# Epoch done[13/30], Step [400/600], Loss: 0.0070, and Accuracy: 99.495%
# Epoch done[13/30], Step [600/600], Loss: 0.0229, and Accuracy: 99.487%
# Epoch done[15/30], Step [200/600], Loss: 0.0001, and Accuracy: 99.665%
# Epoch done[15/30], Step [400/600], Loss: 0.0000, and Accuracy: 99.655%
# Epoch done[15/30], Step [600/600], Loss: 0.0024, and Accuracy: 99.612%
# Epoch done[17/30], Step [200/600], Loss: 0.0004, and Accuracy: 99.700%
# Epoch done[17/30], Step [400/600], Loss: 0.0083, and Accuracy: 99.615%
# Epoch done[17/30], Step [600/600], Loss: 0.0681, and Accuracy: 99.585%
# Epoch done[19/30], Step [200/600], Loss: 0.0002, and Accuracy: 99.635%
# Epoch done[19/30], Step [400/600], Loss: 0.0100, and Accuracy: 99.645%
# Epoch done[19/30], Step [600/600], Loss: 0.0002, and Accuracy: 99.600%
# Epoch done[21/30], Step [200/600], Loss: 0.0002, and Accuracy: 99.865%
# Epoch done[21/30], Step [400/600], Loss: 0.0088, and Accuracy: 99.705%
# Epoch done[21/30], Step [600/600], Loss: 0.0042, and Accuracy: 99.658%
# Epoch done[23/30], Step [200/600], Loss: 0.0057, and Accuracy: 99.670%
# Epoch done[23/30], Step [400/600], Loss: 0.1015, and Accuracy: 99.695%
# Epoch done[23/30], Step [600/600], Loss: 0.0615, and Accuracy: 99.660%
# Epoch done[25/30], Step [200/600], Loss: 0.0000, and Accuracy: 99.810%
# Epoch done[25/30], Step [400/600], Loss: 0.0000, and Accuracy: 99.772%
# Epoch done[25/30], Step [600/600], Loss: 0.0001, and Accuracy: 99.732%
# Epoch done[27/30], Step [200/600], Loss: 0.0000, and Accuracy: 99.700%
# Epoch done[27/30], Step [400/600], Loss: 0.0267, and Accuracy: 99.737%
# Epoch done[27/30], Step [600/600], Loss: 0.0277, and Accuracy: 99.755%
# Epoch done[29/30], Step [200/600], Loss: 0.0000, and Accuracy: 99.700%
# Epoch done[29/30], Step [400/600], Loss: 0.0056, and Accuracy: 99.700%
# Epoch done[29/30], Step [600/600], Loss: 0.0000, and Accuracy: 99.693%
# Training completed!!!
#  ****************************************************************************************************
# CNN3(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=576, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=10, bias=True)
# )
# Epoch done[1/30], Step [200/600], Loss: 0.5349, and Accuracy: 41.625%
# Epoch done[1/30], Step [400/600], Loss: 0.5759, and Accuracy: 61.347%
# Epoch done[1/30], Step [600/600], Loss: 0.2934, and Accuracy: 69.350%
# Epoch done[3/30], Step [200/600], Loss: 0.3167, and Accuracy: 88.815%
# Epoch done[3/30], Step [400/600], Loss: 0.3183, and Accuracy: 88.635%
# Epoch done[3/30], Step [600/600], Loss: 0.4722, and Accuracy: 88.857%
# Epoch done[5/30], Step [200/600], Loss: 0.2274, and Accuracy: 89.495%
# Epoch done[5/30], Step [400/600], Loss: 0.3597, and Accuracy: 89.422%
# Epoch done[5/30], Step [600/600], Loss: 0.5058, and Accuracy: 89.488%
# Epoch done[7/30], Step [200/600], Loss: 0.6990, and Accuracy: 89.770%
# Epoch done[7/30], Step [400/600], Loss: 0.6054, and Accuracy: 89.590%
# Epoch done[7/30], Step [600/600], Loss: 0.2350, and Accuracy: 89.618%
# Epoch done[9/30], Step [200/600], Loss: 0.2827, and Accuracy: 89.620%
# Epoch done[9/30], Step [400/600], Loss: 0.4579, and Accuracy: 89.877%
# Epoch done[9/30], Step [600/600], Loss: 0.3498, and Accuracy: 89.882%
# Epoch done[11/30], Step [200/600], Loss: 0.2447, and Accuracy: 89.735%
# Epoch done[11/30], Step [400/600], Loss: 0.4492, and Accuracy: 89.930%
# Epoch done[11/30], Step [600/600], Loss: 0.3873, and Accuracy: 89.938%
# Epoch done[13/30], Step [200/600], Loss: 0.2593, and Accuracy: 90.685%
# Epoch done[13/30], Step [400/600], Loss: 0.4534, and Accuracy: 90.493%
# Epoch done[13/30], Step [600/600], Loss: 0.2988, and Accuracy: 90.185%
# Epoch done[15/30], Step [200/600], Loss: 0.4161, and Accuracy: 89.945%
# Epoch done[15/30], Step [400/600], Loss: 0.3501, and Accuracy: 90.267%
# Epoch done[15/30], Step [600/600], Loss: 0.7139, and Accuracy: 90.323%
# Epoch done[17/30], Step [200/600], Loss: 0.3105, and Accuracy: 90.410%
# Epoch done[17/30], Step [400/600], Loss: 0.2521, and Accuracy: 90.265%
# Epoch done[17/30], Step [600/600], Loss: 0.3503, and Accuracy: 90.207%
# Epoch done[19/30], Step [200/600], Loss: 0.2352, and Accuracy: 89.870%
# Epoch done[19/30], Step [400/600], Loss: 0.1625, and Accuracy: 89.993%
# Epoch done[19/30], Step [600/600], Loss: 0.4221, and Accuracy: 90.062%
# Epoch done[21/30], Step [200/600], Loss: 0.3505, and Accuracy: 90.165%
# Epoch done[21/30], Step [400/600], Loss: 0.3356, and Accuracy: 90.185%
# Epoch done[21/30], Step [600/600], Loss: 0.3690, and Accuracy: 90.237%
# Epoch done[23/30], Step [200/600], Loss: 0.5906, and Accuracy: 90.190%
# Epoch done[23/30], Step [400/600], Loss: 0.2325, and Accuracy: 90.317%
# Epoch done[23/30], Step [600/600], Loss: 0.5864, and Accuracy: 89.953%
# Epoch done[25/30], Step [200/600], Loss: 0.2983, and Accuracy: 90.530%
# Epoch done[25/30], Step [400/600], Loss: 0.7276, and Accuracy: 90.207%
# Epoch done[25/30], Step [600/600], Loss: 0.4726, and Accuracy: 90.243%
# Epoch done[27/30], Step [200/600], Loss: 0.5694, and Accuracy: 90.140%
# Epoch done[27/30], Step [400/600], Loss: 0.3438, and Accuracy: 89.993%
# Epoch done[27/30], Step [600/600], Loss: 0.4745, and Accuracy: 89.733%
# Epoch done[29/30], Step [200/600], Loss: 0.3329, and Accuracy: 90.080%
# Epoch done[29/30], Step [400/600], Loss: 0.3061, and Accuracy: 89.925%
# Epoch done[29/30], Step [600/600], Loss: 0.1547, and Accuracy: 90.097%
# Training completed!!!
#  ****************************************************************************************************

# %%
def test(model):
    # Test the model
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in loaders['test']:
#             images = Variable(images).view(-1,784)
            test_output, last_layer = model(images)
            pred_y = torch.max(test_output, 1)[1].data.squeeze()
            accuracy = (pred_y == labels).sum().item() / float(labels.size(0))
            pass
    print('Test Accuracy of the model on the 10000 test images: %.2f' % accuracy)

for model in cnn_models:
    test(model)
# Out:
# Test Accuracy of the model on the 10000 test images: 0.15
# Test Accuracy of the model on the 10000 test images: 1.00
# Test Accuracy of the model on the 10000 test images: 0.98
# Test Accuracy of the model on the 10000 test images: 0.94

# %%
fig, ax = plt.subplots(1,2,figsize=(20,6))

Labels = ['Model0','Model1','Model2','Model3']
Colors = ['#800080', '#00FF00', '#0000FF', '#FFFF00']

ax[0].set_title("Accuracy")
ax[1].set_title('Loss')
ax[1].set_yscale('log') 

for idx, model in enumerate(cnn_models):

    ax[0].plot(model_accuracy[idx], c= Colors[idx], label=Labels[idx])

    ax[1].plot(model_loss[idx], c= Colors[idx], label=Labels[idx])

ax[0].legend()   
ax[1].legend()
plt.show()

# %% [markdown]
# # PCA On MNIST Dataset

# %%
copy_train_data = datasets.MNIST(
    root='data',
    train=True,
    transform=ToTensor(),
    download = True,
)

copy_test_data = datasets.MNIST(
    root='data',
    train=False,
    transform=ToTensor(),
    download = False,
)

# %%
print(copy_train_data.targets.size())
print(copy_train_data.data.size())
print(type(copy_train_data.data))
# Out:
# torch.Size([60000])
# torch.Size([60000, 28, 28])
# <class 'torch.Tensor'>

# %%
train_data_features = copy_train_data.data.view(-1,784).numpy()
train_data_targets = copy_train_data.targets.numpy()

test_data_features = copy_test_data.data.view(-1,784).numpy()
test_data_targets = copy_test_data.targets.numpy()

print(train_data_features.shape)
print(train_data_targets.shape)
print(test_data_features.shape)
print(test_data_targets.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
std_df = scaler.fit_transform(train_data_features)
std_df.shape
# Out:
# (60000, 784)

# %%
covar_mat = np.matmul(std_df.T, std_df)
covar_mat.shape
# Out:
# (784, 784)

# %%
from scipy.linalg import eigh
values, vectors = eigh(covar_mat, subset_by_index=(782, 783))
print("Dimensions of Eigen vector:", vectors.shape)
vectors = vectors.T
print("Dimensions of Eigen vector:", vectors.shape)
# Out:
# Dimensions of Eigen vector: (784, 2)
# Dimensions of Eigen vector: (2, 784)

# %%
final_df = np.matmul(vectors, std_df.T)
print("vectros:", vectors.shape, "n", "std_df:", std_df.T.shape, "n", "final_df:", final_df.shape)
# Out:
# vectros: (2, 784) n std_df: (784, 60000) n final_df: (2, 60000)

# %%
import pandas as pd

final_dfT = np.vstack((final_df, train_data_targets)).T
dataFrame = pd.DataFrame(final_dfT, columns = ['pca_1', 'pca_2', 'label'])
dataFrame
# Out:
#           pca_1     pca_2  label
# 0     -4.814790 -0.922159    5.0
# 1     -7.754403  8.708977    0.0
# 2      9.431338  2.328389    4.0
# 3     -3.746318 -6.582173    1.0
# 4      3.133297 -5.183251    9.0
# ...         ...       ...    ...
# 59995 -5.119129 -2.039339    8.0
# 59996 -6.498440  0.607841    3.0
# 59997 -3.230564 -3.777212    5.0
# 59998 -4.948125  1.722369    6.0
# 59999 -6.175386 -1.427251    8.0
#
# [60000 rows x 3 columns]

# %%
import seaborn as sns

sns.FacetGrid(dataFrame, hue='label', height=8).map(sns.scatterplot, 'pca_1', 'pca_2').add_legend()
# Out:
# /software/slurm/spackages/linux-rocky8-x86_64/gcc-12.2.0/anaconda3-2023.09-0-3mhml42fa64byxqyd5fig5tbih625dp2/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
